# %% [markdown]
# #OpenAI 的 Whisper 語音辨識
#
# * 可使用 .txt 檔案放要辨識的清單。
# * 可自訂字幕檔要儲存的資料夾。
# * 可自訂是否要跳過已辨識過的。
# * 改用 yt-dlp 下載影音檔案。
#
# OpenaAI 的 Whisper 是一個自動語音辨識系統，而且有開源，可以在底下的網址中找到:
# * https://github.com/openai/whisper
#
# 結合 Whisper 和 pytube 或其它類似 yt-dlp 的工具，就可以將 Youtube 上的影片或播放清單擷取聲音、儲存語音檔後，進行語音辨識，並生成字幕檔。
#
# 目前在後面程式設定區塊中，語音來源路徑的「url」欄位中，可以填入 Youtube 的影片或影片清單網址。
#
# 接著將其它選項都設定好後，就可以在[程式區塊]中按「執行」的按鈕，開始進行語音辨識了。
#
# Whisper 可辨識中英夾雜、臺語，語言代碼「lang」的欄位要選「Chinese」，如果用「自動判斷」，有時會被當成非中文，而無法辨識出文字。
#
# 程式第一次執行時，因為要安裝及下載自動語音辨識所需要的資料，可能要稍等一下下。

# %%
# 串接自己的雲端硬碟
#from google.colab import drive
#drive.mount('/content/drive')
#%cd /content/drive/MyDrive

# %%
#@title OpenAI Whisper 語音辨識並輸出字幕檔案程式 { vertical-output: true }

#@markdown <b>設定底下的自訂參數後，就可以按左側的執行鈕</b>

#@markdown <b>聲音檔的來源</b>，可以是網址(Youtube影片、撥放清單或是上載後的影片、聲音檔檔案名稱。<br />有多個可以放入 .txt 檔案中(例: list.txt)，一行一個網址或是檔案路徑。
url = "" #@param {type:"string"}
#@markdown <b>語音的語言代碼</b>
lang = 'Chinese' #@param ["Chinese", "English", "Japanese", "Korean", "自動判斷"]
#@markdown <b>輸出為哪一種格式</b>（.srt:字幕檔、.txt:純文字檔）
outputFormat = 'txt' #@param ['srt', 'txt']
#@markdown <b>輸出到哪個資料夾</b>(空白表示使用預設值)
output_path = '' #@param {type:"string"}
#@markdown <b>是否覆蓋已存在的辨識結果</b>(沒勾選會跳過已辨識過的)
overwrite_enable = True #@param { type: 'boolean' }
#@markdown <b>使用哪一種辨識模型</b>（small:快/普通，medium:慢/精準，large:更慢/更精準）
modelType = 'large' #@param ["small" , "medium","large"]
#@markdown <b>是否全部辨識完成，立即下載字幕檔</b>
start_downloading_immediately = True #@param { type: 'boolean' }
#@markdown <b>是否即時顯示語音辨識結果</b>
verbose = True #@param { type: 'boolean' }
#markdown <b>是否使用 yt-dlp 下載 Youtube 聲音檔</b><br />(如果較長的聲音檔下載發生問題時再勾選使用)
#YoutubeDL_enable = False #@param { type: 'boolean' }

#@markdown ---
#@markdown <center><p><font color="blue">以下為指令輸出內容</p></center>

# Install + Import + Config
try: import whisper
except:
  print('install whisper ...')
  ! pip -q install git+https://github.com/openai/whisper.git

try: from yt_dlp import YoutubeDL 
except :
  print('install yt_dlp ...')
  ! pip -q install yt_dlp

  
try: from slugify import slugify
except:
  print('install python-slugify ...')
  ! pip install python-slugify

import re
import os
import google
import torch
import whisper
from whisper.utils import get_writer
from yt_dlp import YoutubeDL
import urllib.request
from slugify import slugify

audioFile = 'source.mp3' #暫存的語音檔檔名
tempFolder = '.' #暫存的資料夾(工作目錄、下載的影音、剛轉好的文字檔)
title = ''
textFileList = [] #記錄轉好的文字檔檔名清單

#檢查輸出文字檔的資料夾是否存在, 不存在就改用預設值
if re.sub('\s', '', output_path) == '' :
  #如果沒有輸入，就輸出到預設的暫存資料夾
  output_path = tempFolder
else :
  if os.path.exists(output_path) :
    if not os.path.isdir(output_path) :
      print(output_path + ' 不是資料夾哦! 改用預設值: '+tempFolder)
      output_path = tempFolder
  else :
    print('指定的輸出目錄 '+output_path+' 不存在, 改用預設值: '+tempFolder)
    output_path = tempFolder

# GPU or CPU
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

def getYoutubePlaylistInfo_ydl(url) :
  """
  使用 yt_dlp 由 Youtbue 播放清單網址擷取各影片的資訊
  :param url: Youtube 影片播放清單網址
  """  
  ydl_opts = {
      'quiet':True,
      #'extract_flat':True
  }
  with YoutubeDL(ydl_opts) as ydl: 
    info_dict = ydl.extract_info(url, download=False)
    #return (info_dict.get('entries', None)) #entries 為清單中的影片, 'webpage_url' 為影片網址
    return info_dict

def getYoutubeTitle_ydl(url) :
  """
  使用 yt_dlp 由 Youtbue 網址擷取影片的標題字
  :param url: Youtube 影片網址
  """  
  ydl_opts = {
      'quiet':True
  }
  with YoutubeDL(ydl_opts) as ydl: 
    info_dict = ydl.extract_info(url, download=False)
    return(info_dict.get('title', None))

def getAudioFromYoutube_ydl(url, output_path, outputFilename):
  """
  使用 yt_dlp 由 Youtbue 網址下載影片的聲音並存檔
  :param url: Youtube 影片網址
  :param output_path: 儲存的資料夾名稱
  :param outputFilename: 聲音檔的檔名
  """
  #filename為去掉副檔名的路徑，以免變成 xxx.mp3.mp3
  filename = os.path.join(output_path, os.path.splitext(outputFilename)[0])
  ydl_opts = {
      'quiet':True,
      'outtmpl':filename,
      'keepvideo':False,
      'format': 'bestaudio/best',
      'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
      #  'preferredquality': '192',
      }],      
      'overwrites':True
  }
  with YoutubeDL(ydl_opts) as ydl: 
    ydl.download(url)

def transcribe(audioFilename, output_path, outputFilename, outputFormat) :
  """
  load whisper model and get transcribe result
  :param audioFilename: audio file to transcribe
  :param output_path: the folder to save result
  :param outputFilename: the filename(without the extension) to save result  
  :param outputFormat: the transcribe result format (thie extension of filename)
  """
  #print(audioFilename+' --> '+output_path+outputFilename+'.'+outputFormat)
  #return 1

  model = whisper.load_model(modelType, device=DEVICE)
  if lang=="自動判斷" :
    print('auto detect language')
    result = model.transcribe(audioFilename, fp16=False, verbose=verbose)    
  else :
    result = model.transcribe(audioFilename, fp16=False, verbose=verbose, language=lang)
  # save result to outputFormat file
  saveToFile(result, output_path, outputFilename, outputFormat)

def saveToFile(result, output_path, filename, fileType='srt') :
  """
  save whisper transcribe result to a file
  :param result: whisper transcribe result
  :param output_path: the folder to save result
  :param filename: the filename(without the extension) to save result  
  :param fileType: the transcribe result format (thie extension of filename)
  """
  # save SRT(full filename : output_path/filename.fileType)
  file_writer = get_writer(fileType, output_path) #whisper get_writer
  #file_writer(result, filename)
  #2023.04.12 因應可標定字的時間截記 word_timestamps 必須傳入 writer_args 參數
  writer_args = {'highlight_words': False, 'max_line_count': None, 'max_line_width': None}
  file_writer(result, filename, writer_args)


#
def getFilenameFromTitle(title) :
  """
  convert title to valid filename
  :param title: text to slugify
  """
  return slugify(title, allow_unicode=True, lowercase=False)

def getOutputTextFilename(filename) :
  fPath = os.path.relpath(output_path)
  return os.path.join(fPath, filename+'.'+outputFormat)

def isOutputTextFileExists(filename) :
  return os.path.exists(getOutputTextFilename(filename))

def removeAudioFile(filename) :
  if os.path.exists(filename) :
    os.remove(filename)

def convertNewLineFormat(filename) :
  if os.path.exists(filename) :
    f = open(filename, 'r+')
    data = f.read()
    data = re.sub('\r', '', data, re.MULTILINE) #remove all \r
    data = re.sub('\n', '\r\n', data, re.MULTILINE) #replace \n to \r\n
    f.seek(0)
    f.write(data)
    f.truncate()
    f.close()

def getAudioAndTranscribe(urlOrFile) :
  filename = audioFile #語音檔檔名(辨識用的暫存檔，用固定的名稱較方便)
  # 分網址或是Colab儲存空間檔案處理
  if re.search('https\:\/\/', urlOrFile) :
    isPlayList = False
    # Youtube 分播放清單跟單一影片處理
    if re.search('youtube\.|youtu\.', urlOrFile) :
      # 建立 Playlist 物件
      #pList = Playlist(urlOrFile)
      videoInfo = getYoutubePlaylistInfo_ydl(urlOrFile)
      isPlayList = True
      #try : title = pList.title
      try : videos = videoInfo['entries']
      except :
        isPlayList = False
      #處理 Youtube 播放清單
      if isPlayList :
        title = videoInfo['title']
        print('\n>>處理 Youtube 播放清單影片: '+title)
        #for video in pList.videos :
        for video in videos :
          #title = video.title #取得Youtube影片的標題字
          title = video['title'] #取得Youtube影片的標題字
          #filename = title+'.mp3'
          print('\n>>> '+title)
          #用影片的標題當主檔名，但需將不適合的字置換或去除
          #convert title to valid filename
          outputFilename = getFilenameFromTitle(title)
          #continue

          #如果設定辨識過的重新辨識(overwrite_enable), 或是輸出字幕檔不存在就呼叫whisper
          if not isOutputTextFileExists(outputFilename) or overwrite_enable :
            # delete the old audio file
            removeAudioFile(filename)
            # download audio from video stream
            #video.streams.get_audio_only().download(tempFolder, filename)
            print('>> 下載影音檔案中...')
            try: getAudioFromYoutube_ydl(video['webpage_url'], tempFolder, filename)
            except:
              print('>>>無法由網址下載影音')

            #print('\n>> 準備進行語音辨識...\n')
            if os.path.exists(filename) :
              print('>>>Whisper 辨識中...\n')
              # load whisper model and get transcribe result
              transcribe(filename, output_path, outputFilename, outputFormat)
            else :
              print('>>>找不到語音檔，請確定影音檔是否已準備好了\n')

          #將輸出的檔名列入結果清單中，方便後續壓縮、下載
          textFileList.append(getOutputTextFilename(outputFilename))
        #title = pList.title #供製作下載壓縮檔用的主檔名
        title = videoInfo['title']
      else :
        # Youtube single video
        #title = YouTube(urlOrFile).title #取得Youtube影片的標題字
        title = videoInfo['title']
        outputFilename = getFilenameFromTitle(title) #用影片的標題當主檔名，但需將不適合的字置換或去除
        #如果設定辨識過的重新辨識(overwrite_enable), 或是輸出字幕檔不存在就呼叫whisper
        if not isOutputTextFileExists(outputFilename) or overwrite_enable :
          # delete the old audio file
          removeAudioFile(filename)
          #getAudioFromYoutube(urlOrFile, tempFolder, filename)
          print('>> 下載影音檔案中...')
          try: getAudioFromYoutube_ydl(videoInfo['webpage_url'], tempFolder, filename)
          except:
            print('>>>無法由網址下載影音')
        #將輸出的檔名列入結果清單中，方便後續壓縮、下載
        textFileList.append(getOutputTextFilename(outputFilename))
    else :
      #非Youtube的網址
      # delete the old audio file
      removeAudioFile(filename)
      isPlayList = False
      if re.search('drive\.google\.com', urlOrFile) :
        #Google drive files
        title = getYoutubeTitle_ydl(urlOrFile) #取得檔名
        outputFilename = getFilenameFromTitle(title) #主檔名，但需將不適合的字置換或去除
        if not isOutputTextFileExists(outputFilename) or overwrite_enable :
          getAudioFromYoutube_ydl(urlOrFile, tempFolder, filename)
        #將輸出的檔名列入結果清單中，方便後續壓縮、下載
        textFileList.append(getOutputTextFilename(outputFilename))
      else :
        # other website
        #os.remove(filename)        
        title = ''
        removeAudioFile(filename)
        print('\n>> 下載影音檔案中...\n')
        try : videoInfo = getYoutubePlaylistInfo_ydl(urlOrFile)
        except:
          print('\n>>> 無法下載該網址的影音資訊 ...\n')
        try: title = videoInfo['title'] #取得標題字
        except:
          title = 'unknow'
        outputFilename = getFilenameFromTitle(title) #用影片的標題當主檔名，但需將不適合的字置換或去除
        try: 
          getAudioFromYoutube_ydl(videoInfo['webpage_url'], tempFolder, filename)
        except:
          print('\n>>> 無法下載影音\n')
        #將輸出的檔名列入結果清單中，方便後續壓縮、下載
        textFileList.append(getOutputTextFilename(outputFilename))
        #! yt-dlp -q --force-overwrites -x --audio-format mp3 -o {audioFile} {url}
  else :
    #Colab儲存空間檔案處理(非網址的影音檔)
    isPlayList = False
    title = os.path.splitext(os.path.basename(urlOrFile))[0] #去掉資料夾名稱及附檔名，只取主檔名
    outputFilename = getFilenameFromTitle(title) #結果輸出檔的主檔名
    filename = urlOrFile #辨識指定的影音檔
    if os.path.exists(filename) :
      #將輸出的檔名列入結果清單中，方便後續壓縮、下載
      textFileList.append(getOutputTextFilename(outputFilename))
      #如果字幕檔已存在，而且不可覆蓋，就故意將語音檔設為不存在的檔名，這樣就不會重新辨識
      if (not overwrite_enable) and isOutputTextFileExists(outputFilename) :
        filename = 'fakeFilename.fake'
  #辨識非播放清單的單一語音檔
  if not isPlayList :
    print('\n>> '+title)
    #convert title to valid filename
    #outputFilename = slugify(title, allow_unicode=True, lowercase=False)
    #outputFilename = getFilenameFromTitle(title)
    # 語音檔存在的話，就進行辨識
    # load whisper model and get transcribe result
    print('\n>> 準備進行語音辨識...\n')
    if os.path.exists(filename) :
      print('>>>Whisper 辨識中...\n')
      transcribe(filename, output_path, outputFilename, outputFormat)
    else :
      print('>>>找不到語音檔，請確定影音檔是否已準備好了\n')
    #  start_downloading_immediately = False
  return title

#解析 .txt 檔案中的清單，一行行進行去抓音檔並進行辨識
def parseTxtFileAndTranscribe(txtFile) :
  if os.path.exists(txtFile) :
    file = open(txtFile, 'r')
    lines = file.readlines()
    file.close()
    #print(len(lines))
    for line in lines :
      line = re.sub('\r|\n', '', line, re.MULTILINE) #去掉所有換行字元
      getAudioAndTranscribe(line)
  else :
    print('找不到檔案: '+txtFile)

if (re.search('https\:\/\/', url) is None) and (not re.search('\.txt$', url, re.IGNORECASE) is None) :
  #解析 .txt 檔中的清單後，再進行辨識
  parseTxtFileAndTranscribe(url)
  title = os.path.splitext(os.path.basename(url))[0] #去掉資料夾名稱及附檔名，只取主檔名
else :
  #直接辨識 url 指定的網址或是檔案
  title = getAudioAndTranscribe(url)

if len(textFileList)>0 and start_downloading_immediately :
  print('download...')
  filenames_list = ''
  for textFile in textFileList :
    #print(textFile)
    if os.path.exists(textFile) :
      convertNewLineFormat(textFile) # replace \n with \r\n (Windows format)
      if os.getcwd() != os.path.dirname(os.path.abspath(textFile)) :
        filename = os.path.basename(textFile)
        #copy textFile to current work directory
        ! cp {textFile} ./
      else :
        filename = textFile
      if filenames_list != '' :
        filenames_list = filenames_list+' '
      filenames_list = filenames_list+filename
  #print(filenames_list)

  if len(textFileList)>1 :
    print('\n壓縮並下載辨識結果')
    outputFilename = slugify(title, allow_unicode=True, lowercase=False)+'-'+outputFormat+'.zip'
    ! zip {outputFilename} -D {filenames_list}
  else :
    print('\n下載辨識結果')
    outputFilename = filenames_list

  google.colab.files.download(outputFilename)
# Out:
# install whisper ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 25.0 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done
# install yt_dlp ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 33.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 22.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 93.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 100.7 MB/s eta 0:00:00
# >> 下載影音檔案中...
#
# >> Shop.com 马杨慧音 2023 马来西亚 美安  分享
#
# >> 準備進行語音辨識...
#
# >>>Whisper 辨識中...
# 100%|█████████████████████████████████████| 2.87G/2.87G [01:00<00:00, 51.4MiB/s]
# [00:00.000 --> 00:04.560] 來跟 Shotokan 公司合作
# [00:04.560 --> 00:09.000] 應該說加入 Shotokan 今年已經滿十二年了
# [00:09.000 --> 00:11.000] 很榮幸有這樣的一個旅程
# [00:11.000 --> 00:13.400] 那我之前來到 Macross 之前呢
# [00:13.400 --> 00:17.400] 我的工作是在一家外商保險的公司裡面呢
# [00:17.400 --> 00:18.400] 擔任處經理
# [00:18.400 --> 00:21.200] 後來有一個機會能夠到總公司呢
# [00:21.200 --> 00:22.400] 擔任專業經理人
# [00:22.400 --> 00:26.000] 主要做的工作就是要制度的設計
# [00:26.000 --> 00:27.600] 教育訓練
# [00:27.600 --> 00:31.400] 以及呢 所有業務單位的這個業務競賽
# [00:31.400 --> 00:34.000] 通通呢 都是我要去協助管理的
# [00:34.000 --> 00:36.400] 也因為這樣子的這個因緣際跡呢
# [00:36.400 --> 00:40.000] 所有人都覺得我非常適合經營 Shotokan
# [00:40.000 --> 00:42.400] 對不對 資歷完整
# [00:42.400 --> 00:45.200] 有這個銷售 還有 Recruit 的背景
# [00:45.200 --> 00:46.200] 而且大家知道嗎
# [00:46.200 --> 00:49.600] 我那時候在總公司的部門就是在做 Recruit
# [00:49.600 --> 00:51.600] 感覺起來是非常適合
# [00:51.600 --> 00:55.000] 但是那時候的我從來都沒有想要創業
# [00:55.000 --> 00:59.800] 也從來沒有想要做主持行銷的任何工作
# [00:59.800 --> 01:01.200] 那很榮幸的呢
# [01:01.200 --> 01:03.600] 是在 2010 年的時候呢
# [01:03.600 --> 01:05.800] 我的生涯有一個非常大的轉彎
# [01:05.800 --> 01:08.400] 2007 年 2008 年因為金融海嘯
# [01:08.400 --> 01:10.200] 加上我先生的創業失敗
# [01:10.200 --> 01:11.800] 在外面投資失敗
# [01:11.800 --> 01:15.000] 我們有欠下大的這個負債
# [01:15.000 --> 01:17.600] 讓我有一個機會能重新審視我的人生
# [01:17.600 --> 01:19.600] 而我來到了 Shotokan
# [01:19.600 --> 01:22.200] 那這是我的整個的路程
# [01:22.200 --> 01:26.000] 簡單的說並不是非常的短暫
# [01:26.000 --> 01:28.000] 將近有 12 年的時間
# [01:28.000 --> 01:31.600] 那我最大的幸運也是我最大的不幸
# [01:31.600 --> 01:35.400] 就是我前面剛開始的那幾年相當的順利
# [01:35.400 --> 01:38.600] 你看我從 2011 年
# [01:38.600 --> 01:41.600] 正式開始經營 Shotokan 正式運作的時候
# [01:41.600 --> 01:43.200] 很快的不到兩年
# [01:43.200 --> 01:47.400] 差不多的時間我就晉升了 PC 專業經理級
# [01:47.400 --> 01:50.200] 那為什麼說特別的幸運也是特別的不幸呢
# [01:50.200 --> 01:52.600] 因為我加入 Shotokan 公司之後
# [01:52.600 --> 01:54.800] 我心裡面只有一個念頭
# [01:54.800 --> 01:57.600] 那個念頭就是我要用最快的速度
# [01:57.600 --> 01:59.600] 最強的姿態
# [01:59.600 --> 02:02.400] 最卓越的這個風姿
# [02:02.400 --> 02:05.200] 拿到這個我們講的持續性的收入
# [02:05.200 --> 02:06.800] 或是額外收入
# [02:06.800 --> 02:09.400] 所以在那個時候簡直是殺紅了眼
# [02:09.400 --> 02:12.600] 所有這個系統當中該要去注意的細節
# [02:12.600 --> 02:15.400] 以及那些應該要去複製的事情
# [02:15.400 --> 02:18.200] 坦白說我都沒有做得很扎實
# [02:18.200 --> 02:21.000] 我心裡之前快速的成功
# [02:21.000 --> 02:24.600] 當然上帝是愛我們的
# [02:24.600 --> 02:27.200] 在我 2013 年的時候
# [02:27.200 --> 02:29.600] 這個一旦一晉升專業經理級
# [02:29.600 --> 02:32.000] 我記得那時候我生小孩
# [02:32.000 --> 02:34.600] 我一回去坐月子兩個月
# [02:34.600 --> 02:38.400] 出關的時候我的團隊有三分之二的人
# [02:38.400 --> 02:40.200] 不做這個生意了
# [02:40.200 --> 02:44.000] 簡單的說我的收入只剩下三分之一
# [02:44.000 --> 02:46.200] 大家知道那個時候
# [02:46.200 --> 02:48.200] 我已經全職做美顏了
# [02:48.200 --> 02:50.000] 加上那個時候我先生
# [02:50.000 --> 02:52.000] 我剛剛說我們家裡有債務
# [02:52.000 --> 02:54.800] 所以這種傑居的感覺
# [02:54.800 --> 02:56.600] 這種匱乏的感覺
# [02:56.600 --> 02:58.600] 這種 怎麼講
# [02:58.600 --> 03:00.200] 貧困的感覺
# [03:00.200 --> 03:01.200] 八面熙來
# [03:01.200 --> 03:03.200] 那是我人生第一次
# [03:03.200 --> 03:05.200] 我決定我要離開美工公司
# [03:05.200 --> 03:07.200] 我不想經營這個生意了
# [03:07.200 --> 03:09.000] 那要離開
# [03:09.000 --> 03:12.000] 加上我先生其實一直都不是很支持我做這個生意
# [03:12.000 --> 03:14.200] 他覺得錢來得太慢
# [03:14.200 --> 03:16.200] 所以那個時候我
# [03:16.200 --> 03:18.200] 就跟著我心裡想說
# [03:18.200 --> 03:20.200] 當初招募我的人是孔沈哥
# [03:20.200 --> 03:22.200] 就是 Johnny
# [03:22.200 --> 03:24.200] 那我要離開我一定要跟他說一聲
# [03:24.200 --> 03:27.200] 於是我就約了孔沈哥
# [03:27.200 --> 03:30.200] 在一個會面我哭得梨花帶背
# [03:30.200 --> 03:32.200] 哭爹喊娘
# [03:32.200 --> 03:34.200] 最主要也是跟他抱怨
# [03:34.200 --> 03:35.200] 人生的不公
# [03:35.200 --> 03:39.200] 以及美安的公司和團隊
# [03:39.200 --> 03:41.200] 對我沒有那麼大的幫助
# [03:41.200 --> 03:45.200] 我講了半天通通都是在發洩我的情緒
# [03:45.200 --> 03:47.200] 並且我就很認真的
# [03:47.200 --> 03:50.200] 看著我這個孔沈哥我的領導人說
# [03:50.200 --> 03:51.200] 我不做了
# [03:51.200 --> 03:52.200] 我要去找一份工作
# [03:52.200 --> 03:55.200] 我先生說對就是要找一份工作
# [03:55.200 --> 03:58.200] 大家知道孔沈哥跟我說了什麼嗎
# [03:58.200 --> 04:01.200] 那個下午我們談了三個小時
# [04:01.200 --> 04:03.200] 在我梨花帶著的哭完之後
# [04:03.200 --> 04:07.200] 孔沈哥他竟然沒有安慰我
# [04:08.200 --> 04:12.200] 更重要的是他也沒有慰留我
# [04:12.200 --> 04:17.200] 這是我人生第一次提詞成沒有被慰留的
# [04:17.200 --> 04:21.200] 對我的自信心造成了更巨大的打擊
# [04:21.200 --> 04:26.200] 但是那三個小時卻影響了我接下來的旅程
# [04:26.200 --> 04:27.200] 總共只有三個重點
# [04:27.200 --> 04:29.200] 大家想知道嗎
# [04:29.200 --> 04:32.200] 第一個重點他跟我說
# [04:32.200 --> 04:37.200] Sophia這個是一個做人的生意
# [04:37.200 --> 04:39.200] 我們在這裡要學做人
# [04:39.200 --> 04:40.200] 你知道嗎
# [04:40.200 --> 04:41.200] 在你沒有晉升
# [04:41.200 --> 04:43.200] 在所有人沒有晉升
# [04:43.200 --> 04:45.200] 總顧問經理之前
# [04:45.200 --> 04:46.200] 就是我們一家店之前
# [04:46.200 --> 04:48.200] 其實都跟做事沒有什麼
# [04:48.200 --> 04:50.200] 做事都可以做得很好
# [04:50.200 --> 04:52.200] 跟做事沒有什麼太大的關係
# [04:52.200 --> 04:57.200] 通常比較有問題的是做人
# [04:57.200 --> 05:01.200] 所以要不是因為他的態度很緩和
# [05:01.200 --> 05:03.200] 我真的以為他是在罵我
# [05:03.200 --> 05:06.200] 還是他真的在罵我
# [05:06.200 --> 05:08.200] 我愣住了
# [05:08.200 --> 05:10.200] 也許在你最傷心的時候
# [05:10.200 --> 05:12.200] 你需要的不是安慰
# [05:12.200 --> 05:14.200] 是一個當口棒的和
# [05:14.200 --> 05:15.200] 然後我就認真的看他
# [05:15.200 --> 05:17.200] 接下來第二件事情
# [05:17.200 --> 05:21.200] 他說永續收入就如同魔戒
# [05:21.200 --> 05:23.200] 他說你戴不戴得住這魔戒
# [05:23.200 --> 05:25.200] 因為你知道你一旦拿到永續收入
# [05:25.200 --> 05:26.200] 戴上魔戒之後
# [05:26.200 --> 05:28.200] 你就回不去了
# [05:28.200 --> 05:33.200] 這個琴會一直鈴一直鈴一直鈴一直鈴
# [05:33.200 --> 05:35.200] 這種感覺你是回不去了
# [05:35.200 --> 05:38.200] 但是就是欲戴皇冠
# [05:38.200 --> 05:40.200] 先沉其重
# [05:40.200 --> 05:42.200] 現在這個階段對你
# [05:42.200 --> 05:43.200] 是非常重要的
# [05:43.200 --> 05:45.200] 你要感恩
# [05:45.200 --> 05:47.200] 你要謝謝這個挫折
# [05:47.200 --> 05:48.200] 因為這個挫折將會帶你
# [05:48.200 --> 05:50.200] 來到更高的地方
# [05:50.200 --> 05:52.200] 這是第二個重點
# [05:52.200 --> 05:54.200] 這個重點其實也沒什麼重點
# [05:54.200 --> 05:55.200] 我那時候是這樣覺得
# [05:55.200 --> 05:56.200] 我聽不懂
# [05:56.200 --> 05:59.200] 我只知道他在安慰我的感覺
# [05:59.200 --> 06:01.200] 第三個重點
# [06:01.200 --> 06:03.200] 他說Sophia
# [06:03.200 --> 06:04.200] 到數一千天
# [06:04.200 --> 06:06.200] 這是一個兩到三年
# [06:06.200 --> 06:07.200] 你認真投入
# [06:07.200 --> 06:10.200] 就會拿到持續性收入的生意
# [06:10.200 --> 06:11.200] 那這一千天
# [06:11.200 --> 06:15.200] 未來將會是你最回味的日子
# [06:15.200 --> 06:16.200] 你的人生的故事
# [06:16.200 --> 06:17.200] 將會從這個地方開始
# [06:17.200 --> 06:18.200] 這是你的旅程
# [06:18.200 --> 06:21.200] 你一定要好好享受
# [06:21.200 --> 06:22.200] 我聽完那個下午
# [06:22.200 --> 06:24.200] 就是大概這三個重點
# [06:24.200 --> 06:25.200] 我回去之後
# [06:25.200 --> 06:27.200] 我其實並不是很理解
# [06:27.200 --> 06:29.200] 馮徵哥要跟我講的境界
# [06:29.200 --> 06:30.200] 大家知道馮徵哥講話
# [06:30.200 --> 06:32.200] 如果跟他熟悉一點
# [06:32.200 --> 06:33.200] 你就知道
# [06:33.200 --> 06:35.200] 他非常的溫和對不對
# [06:35.200 --> 06:36.200] gentle
# [06:36.200 --> 06:37.200] 然後非常的溫柔
# [06:37.200 --> 06:39.200] 總是笑容滿面
# [06:39.200 --> 06:40.200] 但是他說的東西
# [06:40.200 --> 06:42.200] 卻在那一個晚上
# [06:42.200 --> 06:45.200] 在我的心裡面大大的發酵
# [06:45.200 --> 06:49.200] 大家知道失敗是一種恩賜
# [06:49.200 --> 06:51.200] 是一種恩賜
# [06:51.200 --> 06:54.200] 有時候我們在一個人的谷底的時候
# [06:54.200 --> 06:55.200] 你會脫去生命當中
# [06:55.200 --> 06:57.200] 一點不必要的重量
# [06:57.200 --> 06:59.200] 尤其是我這樣被
# [06:59.200 --> 07:01.200] 當頭棒喝的那一刻
# [07:01.200 --> 07:03.200] 那些我夠不夠好
# [07:03.200 --> 07:05.200] 大家怎麼看我
# [07:05.200 --> 07:08.200] 我在我父母親座評價是什麼
# [07:08.200 --> 07:09.200] 大家都有批評指教
# [07:09.200 --> 07:11.200] 我是輸還是贏
# [07:11.200 --> 07:14.200] 這些事情好像變得不大重要
# [07:14.200 --> 07:17.200] 失敗是一種特別的禮物
# [07:17.200 --> 07:18.200] 曾經有人跟我說過
# [07:18.200 --> 07:20.200] 你能夠承受多大的失敗
# [07:20.200 --> 07:22.200] 這句話應該反過來說
# [07:22.200 --> 07:23.200] 因為失敗不用承受
# [07:23.200 --> 07:25.200] 大家知道嗎
# [07:25.200 --> 07:27.200] 失敗你只需要放棄
# [07:27.200 --> 07:28.200] 就隨時可以失敗
# [07:28.200 --> 07:31.200] 這種感覺我們經驗太多次了
# [07:31.200 --> 07:34.200] 但是反過來問我們自己
# [07:34.200 --> 07:36.200] 我可以承受多大的成功
# [07:36.200 --> 07:39.200] 因為選擇成功是另外的一種道路
# [07:39.200 --> 07:41.200] 是人生的另外一個道路
# [07:41.200 --> 07:43.200] 代表你如果要承受
# [07:43.200 --> 07:45.200] 你如果真的要承受夠大的成功
# [07:45.200 --> 07:47.200] 代表你要做夠大的改變
# [07:47.200 --> 07:48.200] 同意嗎
# [07:48.200 --> 07:49.200] 同意
# [07:49.200 --> 07:51.200] 所以那時候我有一個機會
# [07:51.200 --> 07:54.200] 我面臨了我生命當中非常重要的問題
# [07:54.200 --> 07:57.200] 這個問題通常如果我們有夠幸運的話
# [07:57.200 --> 07:59.200] 你會在你人生兩個階段的時候
# [07:59.200 --> 08:00.200] 深刻的問自己
# [08:00.200 --> 08:01.200] 第一個階段就是
# [08:01.200 --> 08:04.200] 當你窮得一無所有的時候
# [08:04.200 --> 08:05.200] 幾乎到底了
# [08:05.200 --> 08:07.200] 好像什麼也不剩了
# [08:07.200 --> 08:08.200] 的時候我會問自己
# [08:08.200 --> 08:09.200] 第二個就是
# [08:09.200 --> 08:10.200] 第二種狀態就是
# [08:10.200 --> 08:12.200] 你什麼都有的時候
# [08:12.200 --> 08:14.200] 你會重新問自己
# [08:14.200 --> 08:16.200] 我到底為什麼來
# [08:16.200 --> 08:18.200] 我為什麼選擇經營學校
# [08:18.200 --> 08:21.200] 持續性收入對我的意義到底是什麼
# [08:21.200 --> 08:24.200] 我想要成為一個什麼樣的人
# [08:25.200 --> 08:26.200] 我現在在
# [08:26.200 --> 08:29.200] 在那一天跟彭神哥溝通完之後
# [08:29.200 --> 08:32.200] 我先生真的很放心的以為我要去工作了
# [08:34.200 --> 08:35.200] 結果在那一天晚上
# [08:35.200 --> 08:38.200] 我實在是痛哭了一場
# [08:38.200 --> 08:39.200] 但痛哭一場的時候
# [08:39.200 --> 08:40.200] 我們有些東西就越來越明白
# [08:40.200 --> 08:41.200] 你知道嗎
# [08:41.200 --> 08:43.200] 這一生我們任何人都可以騙
# [08:43.200 --> 08:45.200] 但你結尾千萬不要騙自己好不好
# [08:45.200 --> 08:47.200] 有些答案我們很清楚
# [08:47.200 --> 08:50.200] 我們可以不斷的去責怪別人
# [08:50.200 --> 08:51.200] 責怪公司
# [08:51.200 --> 08:52.200] 責怪團隊
# [08:52.200 --> 08:54.200] 我們都可以這麼做
# [08:54.200 --> 08:56.200] 但是有些東西我們必須誠實的說
# [08:56.200 --> 08:59.200] 這些不都是我們自己同意的嗎
# [08:59.200 --> 09:00.200] 對不對
# [09:00.200 --> 09:03.200] 所以最大的負責任不是自責
# [09:03.200 --> 09:04.200] 也不是責怪自己
# [09:04.200 --> 09:06.200] 責怪自己不會讓自己有力量
# [09:06.200 --> 09:07.200] 最大的這個負責任是
# [09:07.200 --> 09:09.200] 看清楚問題到底怎麼了
# [09:09.200 --> 09:12.200] 而且我不知道大家有沒有跟我同樣的感覺
# [09:12.200 --> 09:14.200] 失敗和挫折這種東西
# [09:14.200 --> 09:16.200] 在你沒有認清楚它的本質之前
# [09:16.200 --> 09:18.200] 你就這樣離開了
# [09:18.200 --> 09:20.200] 它會在人生的各種角落再發生一次
# [09:20.200 --> 09:22.200] 兩次 三次 四次
# [09:22.200 --> 09:25.200] 只是換了不同的嘴臉
# [09:25.200 --> 09:27.200] 在類似的情境當中再響一巴掌
# [09:27.200 --> 09:29.200] 有沒有這樣的感覺
# [09:29.200 --> 09:30.200] 真的
# [09:30.200 --> 09:33.200] 這件事情我們沒有辦法欺騙自己
# [09:33.200 --> 09:34.200] 我也是
# [09:34.200 --> 09:35.200] 所以我得要弄清楚
# [09:35.200 --> 09:37.200] 我到底哪裡有問題
# [09:37.200 --> 09:40.200] 所以那個時候我就搬出了
# [09:40.200 --> 09:42.200] 在我的倉庫找好久
# [09:42.200 --> 09:44.200] 找到了這一位主
# [09:44.200 --> 09:46.200] 大家記得這個嗎
# [09:46.200 --> 09:49.200] 超連鎖手冊
# [09:49.200 --> 09:51.200] 我記得我開箱之後
# [09:51.200 --> 09:53.200] 它只用了兩個用途
# [09:53.200 --> 09:56.200] 第一個用途就是蓋泡麵
# [09:56.200 --> 09:58.200] 蓋得很嚴實
# [09:58.200 --> 10:00.200] 第二個就是當我失眠的時候
# [10:00.200 --> 10:01.200] 翻開來
# [10:01.200 --> 10:02.200] 跟大家講
# [10:02.200 --> 10:03.200] 我都讀不過第三段
# [10:03.200 --> 10:05.200] 我就睡著了
# [10:05.200 --> 10:06.200] 蓋都不用試
# [10:06.200 --> 10:07.200] 很好睡
# [10:07.200 --> 10:09.200] 我再也沒用過了
# [10:09.200 --> 10:11.200] 我就把它放在倉庫裡
# [10:11.200 --> 10:12.200] 我找了好久
# [10:12.200 --> 10:13.200] 我把它找出來
# [10:13.200 --> 10:14.200] 我只想知道
# [10:14.200 --> 10:15.200] 我錯過了什麼
# [10:15.200 --> 10:17.200] 我到底為什麼
# [10:17.200 --> 10:19.200] 別人拿得到持續性收入
# [10:19.200 --> 10:20.200] 我就不行
# [10:20.200 --> 10:22.200] 人家都說我很優秀
# [10:22.200 --> 10:23.200] 人家都說我很棒
# [10:23.200 --> 10:26.200] 我以前的所有的過往經驗
# [10:26.200 --> 10:27.200] 也讓我覺得
# [10:27.200 --> 10:29.200] 我不應該只有這樣子的表現
# [10:29.200 --> 10:31.200] 我到底錯過了什麼
# [10:31.200 --> 10:33.200] 我得要弄清楚
# [10:33.200 --> 10:34.200] 那一次
# [10:34.200 --> 10:36.200] 我記得那三四天
# [10:36.200 --> 10:38.200] 我把所有的東西
# [10:38.200 --> 10:40.200] 認真認真地讀一次
# [10:40.200 --> 10:41.200] 每個字都讀一次
# [10:41.200 --> 10:42.200] 結果當我認真讀
# [10:42.200 --> 10:43.200] 而且我帶著
# [10:43.200 --> 10:44.200] 我是願意相信
# [10:44.200 --> 10:45.200] 我願意知道
# [10:45.200 --> 10:47.200] 我願意相信這裡面有答案
# [10:47.200 --> 10:48.200] 這樣的態度去念的時候
# [10:48.200 --> 10:50.200] 翻開第一頁就找到答案了
# [10:50.200 --> 10:52.200] 他說
# [10:52.200 --> 10:54.200] 你執行這個事業
# [10:54.200 --> 10:57.200] 你必須先遵循這個系統
# [10:57.200 --> 10:58.200] 首先你得理解
# [10:58.200 --> 11:00.200] 系統到底是什麼
# [11:00.200 --> 11:02.200] 遵循系統是什麼意思
# [11:02.200 --> 11:05.200] 然後你持續累積兩到三年
# [11:05.200 --> 11:08.200] 你會有一個成功的方案
# [11:08.200 --> 11:10.200] 你唯一可能失敗的
# [11:10.200 --> 11:13.200] 就是你半途而廢
# [11:13.200 --> 11:14.200] 第一句話就講了
# [11:14.200 --> 11:15.200] 我也是因為這句話
# [11:15.200 --> 11:16.200] 我開始想
# [11:16.200 --> 11:18.200] 是真的是這樣嗎
# [11:18.200 --> 11:20.200] 我把所有的東西都讀滿一遍
# [11:20.200 --> 11:21.200] 然後呢
# [11:21.200 --> 11:24.200] 我就把我的起步指南拿出來
# [11:24.200 --> 11:25.200] 把成功五要覺得
# [11:25.200 --> 11:27.200] 每一張投影片
# [11:27.200 --> 11:28.200] 全部列印出來
# [11:28.200 --> 11:29.200] 每一個字都看過
# [11:29.200 --> 11:31.200] 我在看這些資料的時候
# [11:31.200 --> 11:32.200] 我問了我幾個
# [11:32.200 --> 11:33.200] 非常重要的問題
# [11:33.200 --> 11:35.200] 第一個問題是
# [11:35.200 --> 11:36.200] 我真的都知道
# [11:36.200 --> 11:38.200] 裡面的每一個字在講什麼嗎
# [11:38.200 --> 11:39.200] 我打開成功五要覺得
# [11:39.200 --> 11:41.200] 我發現如果今天要我去講
# [11:41.200 --> 11:43.200] 這個POPCORN票
# [11:43.200 --> 11:44.200] 我大概只能
# [11:44.200 --> 11:46.200] 硬掰胡扯大概三成
# [11:46.200 --> 11:47.200] 其實有七成
# [11:47.200 --> 11:48.200] 我不知道他在說什麼
# [11:48.200 --> 11:49.200] 這是真實的
# [11:49.200 --> 11:50.200] 那個時候我的狀態
# [11:50.200 --> 11:52.200] 第二個狀況是
# [11:52.200 --> 11:53.200] 我自己做過嗎
# [11:53.200 --> 11:55.200] 好像也沒做過
# [11:55.200 --> 11:56.200] 第三個
# [11:56.200 --> 11:57.200] 我真的用這樣的方式
# [11:57.200 --> 11:59.200] 去帶過夥伴嗎
# [11:59.200 --> 12:01.200] 沒有
# [12:01.200 --> 12:02.200] 我就發現了一個
# [12:02.200 --> 12:04.200] 非常重要的答案
# [12:04.200 --> 12:05.200] 這個答案就是
# [12:05.200 --> 12:06.200] 大家知道嗎
# [12:06.200 --> 12:08.200] 我們都用同一個系統
# [12:08.200 --> 12:10.200] 同一個APP
# [12:10.200 --> 12:12.200] 我們做的是同一個商品賬號
# [12:12.200 --> 12:14.200] 我們用的是同一個產品
# [12:14.200 --> 12:15.200] 可是我們最大的不同
# [12:15.200 --> 12:17.200] 是我們對於美安的認知
# [12:17.200 --> 12:19.200] 有非常大的不同
# [12:19.200 --> 12:21.200] 我們現在的收入
# [12:21.200 --> 12:22.200] 在美安領的收入
# [12:22.200 --> 12:24.200] 是我們認知的邊界
# [12:24.200 --> 12:27.200] 如果你對美安的認知夠深
# [12:27.200 --> 12:29.200] 你的永續收入就越高
# [12:29.200 --> 12:31.200] 如果我們對美安的認知是錢薄
# [12:31.200 --> 12:33.200] 我們做的事是錢薄的
# [12:33.200 --> 12:35.200] 我們領的錢就是少的
# [12:36.200 --> 12:37.200] 所以你們去想想看
# [12:37.200 --> 12:39.200] 我們現在到底理不理解美安
# [12:39.200 --> 12:40.200] 我後來發現
# [12:40.200 --> 12:42.200] 我只是用了美安的外殼
# [12:42.200 --> 12:45.200] 做了一個我自己喜歡的事業
# [12:45.200 --> 12:47.200] 我其實一點都不理解
# [12:47.200 --> 12:49.200] 梅艾莫茲在做些什麼
# [12:49.200 --> 12:50.200] 但也是那一天
# [12:50.200 --> 12:51.200] 我痛定思痛
# [12:51.200 --> 12:53.200] 我告訴我自己
# [12:53.200 --> 12:55.200] 我要讓美安走進我的心裡
# [12:55.200 --> 12:56.200] 從那一刻
# [12:56.200 --> 12:58.200] 我要拿資訊進去收入
# [12:58.200 --> 13:00.200] 認知這個東西很特別
# [13:00.200 --> 13:02.200] 這是世界上最公平的事情
# [13:02.200 --> 13:03.200] 就是你的財富
# [13:03.200 --> 13:05.200] 會跟你的認知是一樣
# [13:05.200 --> 13:08.200] 像我之前不小心晉升PC
# [13:08.200 --> 13:09.200] 那選絕對是好運
# [13:09.200 --> 13:10.200] 大家知道嗎
# [13:10.200 --> 13:12.200] 從好運賺來的錢
# [13:12.200 --> 13:15.200] 就會用你的實力耀光光
# [13:15.200 --> 13:17.200] 同意嗎
# [13:17.200 --> 13:20.200] 至少我自己的狀況是那個樣子
# [13:20.200 --> 13:21.200] 我很開心
# [13:21.200 --> 13:23.200] 在這個認知裡面
# [13:23.200 --> 13:25.200] 我第一個學會的事情是什麼
# [13:25.200 --> 13:26.200] 是耐心
# [13:26.200 --> 13:27.200] 我跟各位講一個
# [13:27.200 --> 13:28.200] 這是真實的
# [13:28.200 --> 13:29.200] 我那時候來到美工廠
# [13:29.200 --> 13:30.200] 我心裡非常的急切
# [13:30.200 --> 13:31.200] 我想要兩到三年
# [13:31.200 --> 13:32.200] 然後再去收入
# [13:32.200 --> 13:33.200] 一勞永逸
# [13:33.200 --> 13:34.200] 然後我就要掰掰
# [13:34.200 --> 13:36.200] 做我想做的人生
# [13:36.200 --> 13:37.200] 我要做自己
# [13:37.200 --> 13:39.200] 其實做自己什麼我也不知道
# [13:39.200 --> 13:41.200] 但是我唯一想要的事情就是
# [13:41.200 --> 13:43.200] 不要再繼續做美安
# [13:43.200 --> 13:44.200] 我誠實說
# [13:44.200 --> 13:46.200] 我那時候的心態就是這個樣子
# [13:46.200 --> 13:48.200] 那種感覺就好像
# [13:48.200 --> 13:49.200] 一個女人
# [13:49.200 --> 13:50.200] 嫁給一個男人
# [13:50.200 --> 13:52.200] 或者跟他交往
# [13:52.200 --> 13:53.200] 兩到三年之後
# [13:53.200 --> 13:57.200] 把他的錢騙光就跟他離婚
# [13:57.200 --> 13:59.200] 概念是差不多的
# [13:59.200 --> 14:02.200] 大家覺得我跟這個男人的感情
# [14:02.200 --> 14:03.200] 你覺得我跟他的感情
# [14:03.200 --> 14:05.200] 感覺是怎麼樣
# [14:05.200 --> 14:07.200] 會幸福嗎
# [14:07.200 --> 14:10.200] 這是一個健康的關係嗎
# [14:10.200 --> 14:12.200] 大家知道我在台灣講這一段的時候
# [14:12.200 --> 14:13.200] 台灣的夥伴說
# [14:13.200 --> 14:17.200] 你八成是想毒死他
# [14:17.200 --> 14:18.200] 毒不毒死他不知道
# [14:18.200 --> 14:19.200] 這個不是真的
# [14:19.200 --> 14:20.200] 但是我能確定一件事
# [14:20.200 --> 14:22.200] 至少我不會很尊重他
# [14:22.200 --> 14:24.200] 同意吧
# [14:24.200 --> 14:26.200] 因為我只是想要那個結果
# [14:26.200 --> 14:29.200] 我想為這個整個過程負責任
# [14:29.200 --> 14:32.200] 所以你知道有很多人跟我一樣
# [14:32.200 --> 14:35.200] 是兩到三年才真正啟動這個聲音
# [14:35.200 --> 14:36.200] 前面可能瞎忙了一場
# [14:36.200 --> 14:39.200] 用自己的方式
# [14:39.200 --> 14:40.200] 我們誤會了
# [14:40.200 --> 14:42.200] 他要給我們了
# [14:42.200 --> 14:43.200] 耐心
# [14:43.200 --> 14:45.200] 尤其對夥伴的耐心
# [14:45.200 --> 14:46.200] 對自己對這個事業的耐心
# [14:46.200 --> 14:48.200] 是最重要的資產
# [14:48.200 --> 14:49.200] 其實有一本書上面說
# [14:49.200 --> 14:52.200] 叫有錢人的習慣跟你不一樣
# [14:52.200 --> 14:54.200] 他說有錢人最重要的資產
# [14:54.200 --> 14:56.200] 其實並不是他手上的錢
# [14:56.200 --> 14:59.200] 而是他對一件事情的耐心
# [14:59.200 --> 15:01.200] 第二個認知
# [15:01.200 --> 15:04.200] 就是意願永遠要大於等
# [15:04.200 --> 15:05.200] 在這個聲音當中
# [15:05.200 --> 15:07.200] 如果有任何行不通的事情
# [15:07.200 --> 15:09.200] 一定是我們的不願意
# [15:09.200 --> 15:10.200] 市長
# [15:10.200 --> 15:11.200] 那我到底不願意什麼
# [15:11.200 --> 15:14.200] 是不願意買三張大會的票
# [15:14.200 --> 15:17.200] 不願意實行GAT的辭職系統
# [15:17.200 --> 15:18.200] 不願意線上合作
# [15:18.200 --> 15:20.200] 不願意去打一通電話
# [15:20.200 --> 15:22.200] 給我們適合的這個候選人
# [15:23.200 --> 15:25.200] 不願意做一對一 二對一
# [15:25.200 --> 15:27.200] 我們到底不願意在哪個地方
# [15:27.200 --> 15:29.200] 哪一個不願意就會卡住我們之後
# [15:29.200 --> 15:31.200] 不是不願意再相信夥伴
# [15:31.200 --> 15:33.200] 而且我跟各位講
# [15:33.200 --> 15:35.200] 這個更神奇的地方是什麼
# [15:35.200 --> 15:36.200] 就是這個生意
# [15:36.200 --> 15:38.200] 一定是從非常小的工作做起的
# [15:38.200 --> 15:39.200] 大家知道嗎
# [15:39.200 --> 15:40.200] 我不曉得大家有沒有感覺
# [15:40.200 --> 15:42.200] 剛剛上來表揚的這些人
# [15:42.200 --> 15:44.200] 接下來你會看到更多的理念
# [15:44.200 --> 15:46.200] 他們的收入高到讓人覺得不可置信
# [15:46.200 --> 15:47.200] 我記得那時候
# [15:47.200 --> 15:48.200] 我十二年前
# [15:48.200 --> 15:50.200] 坐在台底下
# [15:50.200 --> 15:52.200] 我看到那個收入72千馬幣
# [15:52.200 --> 15:54.200] 我簡直都敢相信
# [15:54.200 --> 15:56.200] 你知道我是學金融的
# [15:56.200 --> 15:59.200] 72千馬幣代表他有多麼大的資產
# [15:59.200 --> 16:01.200] 要放在銀行裡面
# [16:01.200 --> 16:04.200] 或是放在一個金融證券裡面
# [16:04.200 --> 16:05.200] 讓他有這樣穩定的收入
# [16:05.200 --> 16:06.200] 那是大錢
# [16:06.200 --> 16:08.200] 你知道我就一直在幻想
# [16:08.200 --> 16:09.200] 我要領這個大錢
# [16:09.200 --> 16:11.200] 一定是來幹大事的
# [16:11.200 --> 16:12.200] 對吧
# [16:12.200 --> 16:13.200] 我就在幻想
# [16:13.200 --> 16:15.200] 我跟各位講韓劇真的不要看太多
# [16:15.200 --> 16:16.200] 因為韓劇上面幹大事
# [16:16.200 --> 16:17.200] 都是霸道總裁
# [16:17.200 --> 16:21.200] 負責在辦公室跟女秘書談戀愛
# [16:21.200 --> 16:22.200] 他就很有錢
# [16:22.200 --> 16:24.200] 真的不是這樣
# [16:24.200 --> 16:26.200] 現實不是這個樣子
# [16:26.200 --> 16:28.200] 當我看到宣傳方在做的事情
# [16:28.200 --> 16:30.200] 有一陣子我是非常抗拒的
# [16:30.200 --> 16:31.200] 列名單
# [16:31.200 --> 16:32.200] 打電話
# [16:32.200 --> 16:34.200] 一對一 二對一
# [16:34.200 --> 16:36.200] 帶一間GMTS系統
# [16:36.200 --> 16:39.200] 上著我們一直以來都上過的課
# [16:39.200 --> 16:41.200] 我其實有一段時間
# [16:41.200 --> 16:44.200] 不敢相信就只是做這樣的事情
# [16:44.200 --> 16:46.200] 可以讓我拿到值薪的收入
# [16:46.200 --> 16:48.200] 然而大家知道嗎
# [16:48.200 --> 16:51.200] 這條道路只有一個一條
# [16:51.200 --> 16:54.200] 有機會讓你拿到我們講的值薪收入
# [16:54.200 --> 16:56.200] 就是要從聰明到老實
# [16:56.200 --> 16:58.200] 老老實實的認認分分的
# [16:58.200 --> 17:00.200] 把這件事情做完
# [17:00.200 --> 17:02.200] 所以為大家翻譯一下
# [17:02.200 --> 17:04.200] 拿到值薪收入有幾個重點
# [17:04.200 --> 17:05.200] 第一個拿到值薪收入的人
# [17:05.200 --> 17:06.200] 只有一種身份
# [17:06.200 --> 17:09.200] 這個身份叫做創業家
# [17:09.200 --> 17:10.200] 創業家
# [17:10.200 --> 17:12.200] 我記得我第一次聽到創業家的時候
# [17:12.200 --> 17:14.200] 是2011年
# [17:14.200 --> 17:15.200] 我在美國
# [17:15.200 --> 17:16.200] 美國的大會
# [17:16.200 --> 17:17.200] 創業家講的
# [17:17.200 --> 17:18.200] 那是我極其的抗拒
# [17:18.200 --> 17:20.200] 因為我不知道創業家是什麼意思
# [17:20.200 --> 17:21.200] 但是感覺就是挺麻煩的
# [17:21.200 --> 17:22.200] 沒完沒了
# [17:22.200 --> 17:25.200] 跟我的當初的預期是不一樣的
# [17:25.200 --> 17:26.200] 我有點害怕
# [17:26.200 --> 17:28.200] 而且感覺要負很多責任
# [17:28.200 --> 17:29.200] 時至今日我才明白
# [17:29.200 --> 17:31.200] 創業家跟你有什麼能力
# [17:31.200 --> 17:32.200] 有多少資產
# [17:32.200 --> 17:34.200] 現在有沒有人跟著你
# [17:34.200 --> 17:35.200] 你的團隊大小
# [17:35.200 --> 17:37.200] 一點關係都沒有
# [17:37.200 --> 17:39.200] 創業家是一種選擇
# [17:39.200 --> 17:42.200] 我記得有一次我聽創業家講年會的時候
# [17:42.200 --> 17:43.200] 他說有些人
# [17:43.200 --> 17:45.200] 他從大會的門口走進來
# [17:45.200 --> 17:47.200] 坐下來那一刻起
# [17:47.200 --> 17:48.200] 他就是The Return
# [17:48.200 --> 17:49.200] 為什麼
# [17:49.200 --> 17:52.200] 是因為他選擇了成為一個創業家
# [17:52.200 --> 17:55.200] 那是一種選擇
# [17:55.200 --> 17:57.200] 2011年的時候我參加美國大會
# [17:57.200 --> 17:59.200] 是一個非常驚奇的之旅
# [17:59.200 --> 18:01.200] 是我第一次參加美國大會
# [18:01.200 --> 18:03.200] 大家知道我在美國大會看到什麼嗎
# [18:03.200 --> 18:05.200] 為什麼要去美國大會
# [18:05.200 --> 18:06.200] 其實說穿得很簡單
# [18:06.200 --> 18:11.200] 因為那時候台灣的這個網站有點興旺
# [18:11.200 --> 18:14.200] 就是大部分我們在搜尋的時候
# [18:14.200 --> 18:16.200] 都是查不到這些東西
# [18:16.200 --> 18:18.200] 什麼都查不到
# [18:18.200 --> 18:20.200] 夥伴上面也非常的少
# [18:20.200 --> 18:23.200] 那這個合作的這個一臂的產品
# [18:23.200 --> 18:25.200] 可是現在的產品也沒那麼多
# [18:25.200 --> 18:28.200] 所以在一切的這個感覺
# [18:28.200 --> 18:29.200] 黃生哥就跟我說了
# [18:29.200 --> 18:31.200] 要去看真香氣
# [18:31.200 --> 18:33.200] 真的要去看真香氣
# [18:33.200 --> 18:34.200] 我就去了
# [18:34.200 --> 18:36.200] 然後到了現場
# [18:36.200 --> 18:37.200] 我以為是每個人都要去
# [18:37.200 --> 18:38.200] 到了現場
# [18:38.200 --> 18:40.200] 我以為是機場集合的人這麼少
# [18:40.200 --> 18:42.200] 但我就是去了
# [18:42.200 --> 18:45.200] 那我去的時候我覺得非常有收穫
# [18:45.200 --> 18:47.200] 我記得我進入美國大會的會場的時候
# [18:47.200 --> 18:49.200] 我看到美國大會有這麼多的BB
# [18:49.200 --> 18:51.200] 這麼多厲害的夥伴商店
# [18:51.200 --> 18:53.200] 甚至那時候就已經
# [18:53.200 --> 18:56.200] 在開始要有即時回饋的IBB的機制
# [18:56.200 --> 18:59.200] 這麼多不可思議的這些
# [18:59.200 --> 19:04.200] 全世界這個上市公司的這些產品的廠商
# [19:04.200 --> 19:05.200] 跟美國公司合作
# [19:05.200 --> 19:07.200] 你知道我那時候心裡在想什麼
# [19:07.200 --> 19:08.200] 我非常的激動
# [19:08.200 --> 19:09.200] 我心裡想
# [19:09.200 --> 19:11.200] 再過幾年就是台灣了
# [19:11.200 --> 19:12.200] 我跟各位講
# [19:12.200 --> 19:13.200] 這如果發生在台灣
# [19:13.200 --> 19:16.200] 我們台灣每一個人一定都做得起來
# [19:16.200 --> 19:18.200] 我真的心裡這樣想
# [19:18.200 --> 19:19.200] 幾年之後
# [19:19.200 --> 19:21.200] 大家有來過台灣大會嗎
# [19:21.200 --> 19:22.200] 有來過的舉手
# [19:22.200 --> 19:24.200] 我認識一下
# [19:24.200 --> 19:25.200] 哇 太棒了
# [19:25.200 --> 19:27.200] 給自己一個掌聲
# [19:29.200 --> 19:30.200] 你們來台灣大會的時候
# [19:30.200 --> 19:34.200] 感覺是不是跟我當初來美國大會的感覺很像
# [19:34.200 --> 19:35.200] 覺得 哇
# [19:35.200 --> 19:36.200] 如果有一天
# [19:36.200 --> 19:39.200] 我們台灣人怎麼可能做不起來
# [19:39.200 --> 19:42.200] 一定是他們沒看懂
# [19:42.200 --> 19:44.200] 是嗎
# [19:45.200 --> 19:47.200] 但是事實上我告訴大家
# [19:47.200 --> 19:48.200] 成功的人的比例
# [19:48.200 --> 19:50.200] 20% 80%
# [19:50.200 --> 19:52.200] 你知道那時候我看到美國大會的時候
# [19:52.200 --> 19:53.200] 他說
# [19:53.200 --> 19:54.200] JR說
# [19:54.200 --> 19:57.200] 這個天空才是極限
# [19:57.200 --> 19:59.200] 一切美安公司要給你的
# [19:59.200 --> 20:01.200] 都是無極限的
# [20:01.200 --> 20:04.200] 以後我們會有AI人工智慧對不對
# [20:04.200 --> 20:06.200] 以後我們的科技裡面
# [20:06.200 --> 20:08.200] 也許會帶領我們走向這條路
# [20:08.200 --> 20:10.200] 都有可能
# [20:10.200 --> 20:12.200] 但是大家知道了嗎
# [20:12.200 --> 20:18.200] 任何數字乘以0都是0
# [20:18.200 --> 20:21.200] 任何無限大的可能
# [20:21.200 --> 20:23.200] 乘以0都是0
# [20:23.200 --> 20:25.200] 那代表什麼意思
# [20:25.200 --> 20:29.200] 代表有些事情真的沒有人可以幫你
# [20:29.200 --> 20:32.200] 什麼事情不能幫你
# [20:32.200 --> 20:35.200] 你的朋友能不能來到大會這件事
# [20:35.200 --> 20:38.200] 我們能不能幫你
# [20:38.200 --> 20:42.200] 你的名單沒有人可以幫你列
# [20:42.200 --> 20:44.200] 我們越不願意打那個電話
# [20:44.200 --> 20:46.200] 越不願意來實體聚會
# [20:46.200 --> 20:49.200] 這件事有沒有人可以幫你
# [20:49.200 --> 20:50.200] 你知道嗎
# [20:50.200 --> 20:53.200] 如果公司給我們的是無極限
# [20:53.200 --> 20:57.200] 那麼創業家就是那個1
# [20:57.200 --> 20:58.200] 你就是那個1
# [20:58.200 --> 21:00.200] 你只需要做到1
# [21:00.200 --> 21:01.200] 1是什麼
# [21:01.200 --> 21:05.200] 1是你身為超年所店主真正的專業
# [21:05.200 --> 21:07.200] 執行公務年金計畫
# [21:07.200 --> 21:09.200] 轉消費為收入
# [21:09.200 --> 21:11.200] 達成Massive WFO不間斷
# [21:11.200 --> 21:13.200] 並複製這個過程
# [21:13.200 --> 21:15.200] 來到GNTS的系統
# [21:15.200 --> 21:17.200] 買下三張大會的票
# [21:17.200 --> 21:19.200] 這幾乎大家耳朵都聽油了
# [21:19.200 --> 21:20.200] 對嗎
# [21:20.200 --> 21:22.200] 而真的我們要做的只有這樣
# [21:22.200 --> 21:24.200] 我跟你之間的距離
# [21:24.200 --> 21:26.200] 你跟這個永續收入的距離
# [21:26.200 --> 21:28.200] 真的就只差這個1
# [21:28.200 --> 21:30.200] 你要讓這一切變現
# [21:30.200 --> 21:33.200] 那麼美安公司將會把這個無極限的資源資金
# [21:33.200 --> 21:37.200] 永恆的財富滿滿的倒進你的口袋
# [21:37.200 --> 21:43.200] 讓你成為你想要成為的那個人
# [21:43.200 --> 21:44.200] 2020年
# [21:44.200 --> 21:47.200] 我的生命當中經歷了一件事
# [21:47.200 --> 21:49.200] 這件事讓我有一個機會問我自己
# [21:49.200 --> 21:51.200] 重新問我自己
# [21:51.200 --> 21:52.200] 2020年的2月
# [21:52.200 --> 21:55.200] 我先生離世了
# [21:55.200 --> 21:57.200] 我跟各位講這一點
# [21:57.200 --> 21:59.200] 這雖然已經沒有那麼相悲了
# [21:59.200 --> 22:04.200] 但是一點也不輕鬆談這個話題
# [22:04.200 --> 22:05.200] 我那時候什麼都有了
# [22:05.200 --> 22:06.200] 在美安公司那時候
# [22:06.200 --> 22:09.200] 我很感謝美安公司除了傷悲以外
# [22:09.200 --> 22:11.200] 我在金錢上面完全不需要顧慮
# [22:11.200 --> 22:15.200] 因為那時候我已經是執行顧問經理級
# [22:15.200 --> 22:16.200] 我從什麼都沒有到什麼都有
# [22:16.200 --> 22:18.200] 而且計畫著買房子
# [22:18.200 --> 22:22.200] 我很難想像
# [22:22.200 --> 22:23.200] 但是我剛剛說過
# [22:23.200 --> 22:24.200] 如果我不夠幸運
# [22:24.200 --> 22:25.200] 我在什麼都有的時候
# [22:25.200 --> 22:27.200] 我會重新問自己
# [22:27.200 --> 22:28.200] 我是誰
# [22:28.200 --> 22:30.200] 我要成為一個什麼樣的人
# [22:30.200 --> 22:33.200] 我要去到哪裡
# [22:33.200 --> 22:37.200] 後來我很清楚知道幾件事
# [22:37.200 --> 22:39.200] 在人生這一陣當中
# [22:39.200 --> 22:41.200] 真正讓你定義成功的
# [22:41.200 --> 22:42.200] 並不只是你賺到財富
# [22:42.200 --> 22:43.200] 剛剛有很多人說
# [22:43.200 --> 22:46.200] 為什麼這些資深潮流連鎖店主
# [22:46.200 --> 22:48.200] 現在還坐在台底下呢
# [22:48.200 --> 22:52.200] 為什麼James郭博士還來到現場呢
# [22:52.200 --> 22:54.200] 為什麼我們要在這裡呢
# [22:54.200 --> 22:57.200] 是不是因為我們賺不夠
# [22:57.200 --> 22:58.200] 大家知道嗎
# [22:58.200 --> 22:59.200] 如果是為了錢
# [22:59.200 --> 23:02.200] 我們今天都不會來的
# [23:02.200 --> 23:03.200] 真的不會來
# [23:03.200 --> 23:04.200] 因為真正的成功
# [23:04.200 --> 23:06.200] 是在你的生命當中
# [23:06.200 --> 23:09.200] 除了養家活口
# [23:09.200 --> 23:10.200] 除了財富自由之外
# [23:10.200 --> 23:13.200] 一定有些東西是你內在最深的價值
# [23:13.200 --> 23:14.200] 最渴望的東西
# [23:14.200 --> 23:16.200] 最快樂的東西
# [23:16.200 --> 23:18.200] 必須去找到它
# [23:18.200 --> 23:19.200] 必須去追求它
# [23:19.200 --> 23:21.200] 你才會真正的快樂
# [23:21.200 --> 23:24.200] 你人生才會達到一種滿足
# [23:24.200 --> 23:25.200] 所以後來我就發現
# [23:25.200 --> 23:27.200] 目標真的不是來這邊賺到錢
# [23:27.200 --> 23:29.200] 是成為一個真正心態上
# [23:29.200 --> 23:31.200] 生命中富有的人
# [23:31.200 --> 23:32.200] 不是招募到人
# [23:32.200 --> 23:33.200] 而是成為一個領導者
# [23:33.200 --> 23:34.200] 不是要減肥
# [23:34.200 --> 23:36.200] 是要成為一個身體健康
# [23:36.200 --> 23:37.200] 體態健康的人
# [23:37.200 --> 23:39.200] 不是要無止盡的陪小孩
# [23:39.200 --> 23:41.200] 而是要成為一個很棒的母親
# [23:41.200 --> 23:43.200] 不是只是要讓父母退休
# [23:43.200 --> 23:45.200] 而是你要成為一個孝順的孩子
# [23:45.200 --> 23:46.200] 榮耀你的父母
# [23:46.200 --> 23:48.200] 不是只要讓你的另外一半滿意
# [23:48.200 --> 23:49.200] 而是你要成為他一生
# [23:49.200 --> 23:51.200] 對他最有幫助的伴侶
# [23:51.200 --> 23:52.200] 不是要做美安
# [23:52.200 --> 23:53.200] 不是要做美安
# [23:53.200 --> 23:57.200] 而是要成為一個創業家
# [23:57.200 --> 23:59.200] 去年JR八月分離時
# [23:59.200 --> 24:01.200] 對我來說
# [24:01.200 --> 24:03.200] 我簡直不敢相信
# [24:03.200 --> 24:04.200] 我花了非常多的時間
# [24:04.200 --> 24:08.200] 去想怎麼會這個樣子
# [24:08.200 --> 24:10.200] 但是大家有看到Lauren嗎
# [24:10.200 --> 24:13.200] 看到Corporate Team嗎
# [24:13.200 --> 24:15.200] 我跟各位講
# [24:15.200 --> 24:17.200] 那真是一個不容易的過程
# [24:17.200 --> 24:19.200] 我記得我先生走的時候
# [24:19.200 --> 24:21.200] 我有好長的時間
# [24:21.200 --> 24:23.200] 我都不大能定義我自己
# [24:23.200 --> 24:26.200] 我也不知道接下來該為什麼而做
# [24:26.200 --> 24:29.200] 可是我看到Lauren用最快的速度
# [24:29.200 --> 24:32.200] 回復她的狀態
# [24:32.200 --> 24:33.200] 她可以選擇
# [24:33.200 --> 24:35.200] 任何一個更容易的決定
# [24:35.200 --> 24:36.200] 對嗎
# [24:36.200 --> 24:39.200] 如果為了價差
# [24:39.200 --> 24:41.200] 如果只是為了賺錢
# [24:41.200 --> 24:44.200] 她可以做一個更容易的決定
# [24:44.200 --> 24:46.200] 可是她沒有
# [24:46.200 --> 24:47.200] 她選了一個高貴
# [24:47.200 --> 24:48.200] 但是困難的決定
# [24:48.200 --> 24:52.200] 這不是一個容易走的路
# [24:52.200 --> 24:53.200] 大家知道這個
# [24:53.200 --> 24:56.200] 是要付多大的代價嗎
# [24:56.200 --> 24:58.200] 我個人非常深深的佩服她
# [24:58.200 --> 24:59.200] 而我再次指望
# [24:59.200 --> 25:00.200] 我來到一個
# [25:00.200 --> 25:01.200] 各位
# [25:01.200 --> 25:03.200] 我來到一個非常偉大的公司
# [25:03.200 --> 25:05.200] 這邊有非常棒的領導人
# [25:05.200 --> 25:08.200] 他們不只是為了他們的生命在運作
# [25:08.200 --> 25:10.200] 他也為了我們所有人的生命
# [25:10.200 --> 25:11.200] 和家庭夢想
# [25:11.200 --> 25:15.200] 在推動這家公司
# [25:15.200 --> 25:16.200] 所以真正的這個成功
# [25:16.200 --> 25:18.200] 就在於我們到底為這個世界
# [25:18.200 --> 25:22.200] 留下多麼有價值的事情
# [25:22.200 --> 25:23.200] 我們為這個耳朵
# [25:23.200 --> 25:28.200] 你會做得又長又圓又快樂
# [25:28.200 --> 25:30.200] 調整你的認知
# [25:30.200 --> 25:32.200] 幫助他人
# [25:32.200 --> 25:35.200] 我記得在12年前的這個時候
# [25:35.200 --> 25:38.200] 黃昇哥招募我
# [25:38.200 --> 25:40.200] 他招募我的故事很精彩
# [25:40.200 --> 25:41.200] 但是最精彩的部分
# [25:41.200 --> 25:43.200] 不是那個過程
# [25:43.200 --> 25:44.200] 是結束
# [25:44.200 --> 25:46.200] 在一個小時又15分鐘的時候
# [25:46.200 --> 25:49.200] 突然拿出了十張大會的門票
# [25:49.200 --> 25:50.200] 答他怎麼
# [25:50.200 --> 25:52.200] 那禮大會只有兩週
# [25:52.200 --> 25:54.200] 我沒有來過大會
# [25:54.200 --> 25:57.200] 他拿了十張大會的門票
# [25:57.200 --> 25:58.200] 跟我說
# [25:58.200 --> 25:59.200] Sophia
# [25:59.200 --> 26:01.200] 帶著你的夢想去買票
# [26:01.200 --> 26:03.200] 用票實現你的夢想
# [26:03.200 --> 26:04.200] 我傻眼
# [26:04.200 --> 26:07.200] 6千塊馬幣買了十張紙
# [26:07.200 --> 26:09.200] 更重要是兩個禮拜沒用完
# [26:09.200 --> 26:12.200] 他就變廢紙
# [26:12.200 --> 26:13.200] 我到哪裡去弄人
# [26:13.200 --> 26:14.200] 我也不清楚
# [26:14.200 --> 26:16.200] 但他的態度就是
# [26:16.200 --> 26:19.200] 既如以往的誠懇和堅定
# [26:19.200 --> 26:21.200] 我回想那一刻
# [26:21.200 --> 26:22.200] 大家知道嗎
# [26:22.200 --> 26:27.200] 那是我生命當中最缺錢的時候
# [26:27.200 --> 26:28.200] 就是大家知道
# [26:28.200 --> 26:29.200] 窮和非常窮
# [26:29.200 --> 26:33.200] 其實本質上沒有太大的差別
# [26:33.200 --> 26:36.200] 在那個時候他竟然拿出十張票
# [26:36.200 --> 26:38.200] 他是不是在開我的玩笑
# [26:38.200 --> 26:39.200] 我竟然花了6千塊
# [26:39.200 --> 26:41.200] 沒有拿到一貫酵素
# [26:41.200 --> 26:43.200] 買了十張紙
# [26:43.200 --> 26:47.200] 完全不敢相信的看著他
# [26:47.200 --> 26:51.200] 可是他既如以往的堅定
# [26:51.200 --> 26:53.200] 有的時候我們就要碰到一些人
# [26:53.200 --> 26:56.200] 他比你更相信你自己對嗎
# [26:56.200 --> 26:59.200] 我相信他那時候看著我
# [26:59.200 --> 27:02.200] 他相信我比我的困難大很多
# [27:02.200 --> 27:03.200] 他必須這樣看待我
# [27:03.200 --> 27:06.200] 我說我自己一點機會都沒有
# [27:06.200 --> 27:09.200] 大家知道他賣多少票給孟涵姐嗎
# [27:09.200 --> 27:10.200] 20張
# [27:10.200 --> 27:12.200] 大會期一個禮拜
# [27:12.200 --> 27:14.200] 你知道孟涵姐為什麼評級也比我高嗎
# [27:14.200 --> 27:15.200] 因為她偏心
# [27:15.200 --> 27:17.200] 她少賣我10張
# [27:17.200 --> 27:19.200] 這筆帳算不完
# [27:19.200 --> 27:23.200] 給她一掌聲好不好
# [27:23.200 --> 27:24.200] 這是真實的故事
# [27:24.200 --> 27:25.200] 真的是真的
# [27:25.200 --> 27:27.200] 可是當下我拿那個票的時候
# [27:27.200 --> 27:29.200] 我回到家又被我老公罵一頓
# [27:29.200 --> 27:31.200] 他說你真是衝動的
# [27:31.200 --> 27:32.200] 我說沒有
# [27:32.200 --> 27:33.200] 你真是膚淺
# [27:33.200 --> 27:34.200] 我為了證明我不是衝動
# [27:34.200 --> 27:35.200] 他是膚淺
# [27:35.200 --> 27:38.200] 我拼了命的買票
# [27:38.200 --> 27:39.200] 當然沒有不賣
# [27:39.200 --> 27:41.200] 我買完我只賣了8張
# [27:41.200 --> 27:46.200] 但是我而今讓我有機會站在這裡
# [27:46.200 --> 27:49.200] 所以大家
# [27:49.200 --> 27:52.200] 謝謝
# [27:52.200 --> 27:55.200] 這也堅定了我們為什麼要做這件事
# [27:55.200 --> 27:58.200] 撿起海星的過程其實有時候並不容易
# [27:58.200 --> 28:01.200] 你必須相信那些海星會活
# [28:01.200 --> 28:02.200] 對吧
# [28:02.200 --> 28:04.200] 否則你沒有撿他的任何意義
# [28:04.200 --> 28:05.200] 對吧
# [28:05.200 --> 28:06.200] 在你的夥伴
# [28:06.200 --> 28:08.200] 在現在我知道大家都很幸福
# [28:08.200 --> 28:10.200] 我沒有輕看各位的辛苦過
# [28:10.200 --> 28:12.200] 我知道三張大會的門票
# [28:12.200 --> 28:16.200] 幾乎抵過很多人半個月甚至一個月的工資
# [28:16.200 --> 28:18.200] 是嗎
# [28:18.200 --> 28:22.200] 但是如果有機會讓你在三年後五年後
# [28:22.200 --> 28:25.200] 一個月領40千馬幣
# [28:25.200 --> 28:29.200] 這個數字是不是很值得
# [28:29.200 --> 28:31.200] 如果能夠讓你更愛的人
# [28:31.200 --> 28:33.200] 能夠拿到這樣的機會
# [28:33.200 --> 28:36.200] 是不是很值得
# [28:36.200 --> 28:39.200] 三張大會的票
# [28:39.200 --> 28:41.200] 成為領導人
# [28:41.200 --> 28:45.200] 用票支持他人完成夢想
# [28:45.200 --> 28:47.200] 我們只能用票
# [28:47.200 --> 28:51.200] 證明我們自己在這個地方所有的價值
# [28:51.200 --> 28:53.200] 沙漠開江河
# [28:53.200 --> 28:55.200] 荒野開道路
# [28:55.200 --> 28:57.200] 願上帝祝福我們謝謝
# download...
#
# 下載辨識結果
